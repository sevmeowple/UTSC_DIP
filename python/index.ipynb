# %%
import cv2
import numpy as np
from utils.enhance import EnhanceUtils

# %%
img = cv2.imread('../pics/Lena.bmp', cv2.IMREAD_COLOR)
enhancer = EnhanceUtils()

enhancer.plotHistogram(img)

# %%
# from rgb to hsi
import 

gen = [
    122,144,55
]

def rgb2hsi():
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 10
#       5 gen = [
#       6     122,144,55
#       7 ]
#       9 enhancer = EnhanceUtils()
# ---> 10 gen_hsi = enhancer.rgb2hsi(gen)
#      11 gen_hsi
#
# AttributeError: 'EnhanceUtils' object has no attribute 'rgb2hsi'
